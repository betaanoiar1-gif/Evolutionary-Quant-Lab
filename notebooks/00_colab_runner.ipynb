# %% [markdown]
# # Evolutionary Quant Strategy Laboratory
#
# Colab is execution only. Source code remains in GitHub.

# %%
# !git clone -q https://github.com/betaanoiar1-gif/Evolutionary-Quant-Lab.git
# %cd Evolutionary-Quant-Lab
# !pip install -q -e .

# %%
# !python run_lab.py
